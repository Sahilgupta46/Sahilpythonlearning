# %%
size = int(input("Enter the size of the list:"))
food = []
price = []
QT = []
total_price = []

for i in range(size):
  f = str(input("Enter the food:"))
  food.append(f)

for i in range(size):
  p = int(input("Enter the price:"))
  price.append(p)

for i in range(size):
  Q =int(input("Enter the quantity:"))
  QT.append(Q)

for i in range (size):
    print(i,'.',food[i],'=',price[i],'*',QT[i],'/-')

Add = input('Do you want add more food [Y/N]')
if Add == 'Y':
  f = str(input("Enter the food:"))
  food.append(f)

  p = int (input("Enter the price:"))
  price.append(p)

  Q =int(input("Enter the quantity:"))
  QT.append(Q)
  size = size+1

elif Add == 'N':
  print("Thank you")


GST = input('Do you want add GST[Y/N]')
if GST == 'Y':
  for i in range (size):
    print(i,'.',food[i],'=',price[i],'*',QT[i],'/-')
    total_price.append( price[i]*QT[i])

  total = sum(total_price)
  print('Total=',total)
  print('GST =',18,'%')
  final =(total + (total/100)*18)
  print("Final Amount :",final)
  print("Thank You")

elif GST == 'N':
  for i in range (size):
    print(i,'.',food[i],'=',price[i],'=',QT[i],'/-')
  total = sum(price)
  print('Total =',total)
  print("Thank You")

else:
   ()
# Out:
# Enter the size of the list:3
# Enter the food:Samosa
# Enter the food:Kachori
# Enter the food:Vada
# Enter the price:20
# Enter the price:30
# Enter the price:40
# Enter the quantity:2
# Enter the quantity:3
# Enter the quantity:4
# 0 . Samosa = 20 * 2 /-
# 1 . Kachori = 30 * 3 /-
# 2 . Vada = 40 * 4 /-
# Do you want add more food [Y/N]Y
# Enter the food:Pizza
# Enter the price:99
# Enter the quantity:2
# Do you want add GST[Y/N]Y
# 0 . Samosa = 20 * 2 /-
# 1 . Kachori = 30 * 3 /-
# 2 . Vada = 40 * 4 /-
# 3 . Pizza = 99 * 2 /-
# Total= 488
# GST = 18 %
# Final Amount : 575.84
# Thank You
